# %%
import pandas as pd
data = pd.read_csv('cereal.csv')

# %%
data.head()
# Out:
#                  Cereal Name    Manufacturer Type  Calories  Protein (g)  Fat  \
# 0                  100%_Bran         Nabisco    C        70            4    1
# 1          100%_Natural_Bran     Quaker Oats    C       120            3    5
# 2                   All-Bran        Kelloggs    C        70            4    1
# 3  All-Bran_with_Extra_Fiber        Kelloggs    C        50            4    0
# 4             Almond_Delight  Ralston Purina    C       110            2    2
#
#    Sodium  Dietary Fiber  Carbs  Sugars  Display Shelf  Potassium  \
# 0     130           10.0    5.0       6              3        280
# 1      15            2.0    8.0       8              3        135
# 2     260            9.0    7.0       5              3        320
# 3     140           14.0    8.0       0              3        330
# 4     200            1.0   14.0       8              3         -1
#
#    Vitamins and Minerals  Serving Size Weight  Cups per Serving
# ...

# %%
series = data['Cereal Name']
series
# Out:
# 0                     100%_Bran
# 1             100%_Natural_Bran
# 2                      All-Bran
# 3     All-Bran_with_Extra_Fiber
# 4                Almond_Delight
#                 ...
# 69                      Triples
# 70                         Trix
# 71                   Wheat_Chex
# 72                     Wheaties
# 73          Wheaties_Honey_Gold
# Name: Cereal Name, Length: 74, dtype: object

# %%
series.head()
# Out:
# 0                    100%_Bran
# 1            100%_Natural_Bran
# 2                     All-Bran
# 3    All-Bran_with_Extra_Fiber
# 4               Almond_Delight
# Name: Cereal Name, dtype: object

# %%
import re

# %%
data.dropna(inplace = True)
desc=data["Cereal Name"].describe()
desc
# Out:
# count                    74
# unique                   74
# top       Total_Raisin_Bran
# freq                      1
# Name: Cereal Name, dtype: object

# %%
data = pd.read_csv("cereal.csv", index_col ="Cereal Name")
data
# Out:
#                              Manufacturer Type  Calories  Protein (g)  Fat  \
# Cereal Name
# 100%_Bran                         Nabisco    C        70            4    1
# 100%_Natural_Bran             Quaker Oats    C       120            3    5
# All-Bran                         Kelloggs    C        70            4    1
# All-Bran_with_Extra_Fiber        Kelloggs    C        50            4    0
# Almond_Delight             Ralston Purina    C       110            2    2
# ...                                   ...  ...       ...          ...  ...
# Triples                     General Mills    C       110            2    1
# Trix                        General Mills    C       110            1    1
# Wheat_Chex                 Ralston Purina    C       100            3    1
# Wheaties                    General Mills    C       100            3    1
# Wheaties_Honey_Gold         General Mills    C       110            2    1
#
# ...

# %%
first = data.loc["100%_Bran"] 
second = data.loc["All-Bran"]

# %%
print(first, "\n\n\n", second)
# Out:
# Manufacturer             Nabisco
# Type                           C
# Calories                      70
# Protein (g)                    4
# Fat                            1
# Sodium                       130
# Dietary Fiber                 10
# Carbs                          5
# Sugars                         6
# Display Shelf                  3
# Potassium                    280
# Vitamins and Minerals         25
# Serving Size Weight            1
# Cups per Serving            0.33
# Name: 100%_Bran, dtype: object
#
#
#  Manufacturer             Kelloggs
# Type                            C
# Calories                       70
# Protein (g)                     4
# Fat                             1
# Sodium                        260
# Dietary Fiber                   9
# Carbs                           7
# Sugars                          5
# Display Shelf                   3
# Potassium                     320
# Vitamins and Minerals          25
# Serving Size Weight             1
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('cereal.csv')
data
# Out:
#                   Cereal Name    Manufacturer Type  Calories  Protein (g)  \
# 0                   100%_Bran         Nabisco    C        70            4
# 1           100%_Natural_Bran     Quaker Oats    C       120            3
# 2                    All-Bran        Kelloggs    C        70            4
# 3   All-Bran_with_Extra_Fiber        Kelloggs    C        50            4
# 4              Almond_Delight  Ralston Purina    C       110            2
# ..                        ...             ...  ...       ...          ...
# 69                    Triples   General Mills    C       110            2
# 70                       Trix   General Mills    C       110            1
# 71                 Wheat_Chex  Ralston Purina    C       100            3
# 72                   Wheaties   General Mills    C       100            3
# 73        Wheaties_Honey_Gold   General Mills    C       110            2
#
#     Fat  Sodium  Dietary Fiber  Carbs  Sugars  Display Shelf  Potassium  \
# ...

# %%
plt.bar(x=data['Calories'],height=data['Cups per Serving'])
plt.xlabel('Calories')
plt.ylabel('Cups per Serving')
# Out:
# Text(0, 0.5, 'Cups per Serving')

# %%
x = data.Calories
y = data['Cups per Serving']
plt.scatter(x,y)
plt.show()

# %%
pt = sns.distplot(data['Calories'])
# Out:
# d:\python\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data.boxplot(by ='Calories', column =['Cups per Serving'], grid = False)
# Out:
# <AxesSubplot:title={'center':'Cups per Serving'}, xlabel='Calories'>

# %%
fig, ax = plt.subplots(figsize=(8,5))
sns.heatmap(data.corr(), center=0, cmap='Blues')
ax.set_title('Heatmap')
# Out:
# Text(0.5, 1.0, 'Heatmap')

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [15,82,33,6,95] 
y = [27,48,69,32,0] 
plt.plot(x,y) 
plt.show()

# %%
x = [1,2,3] 
y = [2,4,6] 

plt.plot(x, y, label = "line1") 

x1 = [1,2,3] 
y1 = [4,8,3] 

plt.plot(x1, y1, label = "line2") 

plt.xlabel('x-axis') 

plt.ylabel('y-axis') 

plt.title('Two lines on one graph') 

plt.legend() 

plt.show()

# %%
x = [2,4,6,8,10,12] 

y = [6,9,1,5,2,6] 


plt.plot(x, y, color='pink', linestyle='dashed', linewidth = 3, marker='o', markerfacecolor='yellow', markersize=12) 

plt.ylim(1,8) 
plt.xlim(1,8) 

plt.xlabel('x-axis') 

plt.ylabel('y-axis') 

plt.show()

# %%
food = ['Burgerking', 'Mcdonalds', 'KFC', 'TexasChicken'] 

s = [6, 10, 8, 6] 

colors = ['r', 'y', 'g', 'b'] 

plt.pie(s, labels = food, colors=colors, startangle=90, shadow = True, explode = (0.2, 0, 0, 0), radius = 1.2, autopct = '%1.1f%%') 

plt.legend() 

plt.show()

# %%
x = np.arange(0, 10*(np.pi), 0.52) 
y = np.sin(x) 

plt.plot(x, y) 

plt.show()

# %%
xlist = np.linspace(-10.0, 10.0, 100)
ylist = np.linspace(-5.0,53.0, 100)
X, Y = np.meshgrid(xlist, ylist)
Z = np.sqrt(X**2 + Y**2)
fig,ax=plt.subplots(1,1)
cp = ax.contourf(X, Y, Z)
fig.colorbar(cp) 
ax.set_title('Filled Contours Plot')
ax.set_ylabel('y (cm)')
plt.show()

# %%
np.random.seed(10) 
data_1 = np.random.normal(10, 10, 500) 
data_2 = np.random.normal(80, 20, 500) 
data_3 = np.random.normal(40, 30, 500) 
data_4 = np.random.normal(70, 40, 500) 
data = [data_1, data_2, data_3, data_4] 

fg = plt.figure(figsize =(10, 7)) 

axis = fg.add_axes([0, 0, 1, 1]) 
 
bp = axis.boxplot(data) 

plt.show()

# %%
import matplotlib.image as mpimg
img = mpimg.imread('1.png')
plt.imsave("logo.png", img , cmap = 'gray')
imgplot = plt.imshow(img)
